# %% [markdown]
# # Import Libraries & Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-289-g526e650 Python-3.8.13 torch-1.13.0.dev20220730 CPU
# Setup complete ✅ (10 CPUs, 32.0 GB RAM, 391.6/926.4 GB disk)

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# wandb: Currently logged in as: shaunjth92. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # 1. Train

# %%
# !pip install wandb --upgrade

# %%
# Train YOLOv5x
# !python train.py --device mps --img 640 --batch 32 --epochs 300 --data lta_data_3.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: shaunjth92. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=lta_data_3.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=mps, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 47 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-289-g526e650 Python-3.8.13 torch-1.13.0.dev20220730 MPS
#
# ...

# %%
# Resume Training Current data
# !python train.py --resume runs/train/exp50/weights/last.pt

# %%
# Resume Training previous data
# !python train.py --resume runs/train/exp47/weights/last.pt

# %% [markdown]
# # 2. Validate

# %%
# Run YOLOv5x on COCO test
# !python val.py --device cpu --weights best.pt --data lta_data_3.yaml --img 640 --iou 0.65 --half --task test
# Out:
# val: data=/Users/shauntoh/Documents/GitHub/yolov5/data/lta_data_3.yaml, weights=['best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=test, device=cpu, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-289-g526e650 Python-3.8.13 torch-1.13.0.dev20220730 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7104520 parameters, 0 gradients, 16.0 GFLOPs
# test: Scanning '/Users/shauntoh/Documents/GitHub/yolov5/Train_Images_2/test/labe
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       1770       3372      0.827       0.38      0.402      0.262
# 0_person_helmet_vest       1770       1179      0.922      0.338      0.539      0.276
#      1_person_helmet       1770        125      0.892      0.664      0.674       0.37
# ...

# %% [markdown]
# # 3. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --device cpu --weights best.pt --img 640 --conf 0.25 --source vid.mp4
display.Image(filename='/Users/shauntoh/Documents/GitHub/yolov5/runs/detect/exp/OR_CCTV2_NVR_NVR_20220720111600_20220720111900_538098066.mp4', width=600)

# %%
# !python detect.py --device cpu --weights best.pt --img 640 --conf 0.25 --source /Users/shauntoh/Documents/GitHub/yolov5/data/Video/OR_CCTV2_NVR_NVR_20220720103000_20220720103500_537926816.mp4
# Out:
# detect: weights=['best.pt'], source=/Users/shauntoh/Documents/GitHub/yolov5/data/Video/OR_CCTV2_NVR_NVR_20220720103000_20220720103500_537926816.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-289-g526e650 Python-3.8.13 torch-1.13.0.dev20220730 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7104520 parameters, 0 gradients, 16.0 GFLOPs
# video 1/1 (1/15000) /Users/shauntoh/Documents/GitHub/yolov5/data/Video/OR_CCTV2_NVR_NVR_20220720103000_20220720103500_537926816.mp4: 384x640 2 0_person_helmet_vests, 3 18_excavators, 3 19_cranes, Done. (0.051s)
# ...
